# %% [markdown]
# # Get listing pages

# %%
import os
import re
import time

from datetime import date
from seleniumwire import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

import chromedriver_binary

# %% [markdown]
# ## Set up browser and driver

# %%
def open_browser(headless=False):
    """
    Opens a new automated browser window with all tell-tales of automated browser disabled
    """
    options = webdriver.ChromeOptions()
    options.add_argument("start-maximized")
    if headless:
        options.add_argument("--headless")
    
    # remove all signs of this being an automated browser
    options.add_argument('--disable-blink-features=AutomationControlled')
    options.add_experimental_option("excludeSwitches", ["enable-automation"])
    options.add_experimental_option('useAutomationExtension', False)

    # open the browser with the new options
    driver = webdriver.Chrome(options=options)
    return driver

# %%
class CPLSeleniumManager:
    """
    Object to hold/access Selenium webdriver instance and 
    set up destination directories for scraper.
    """
    def __init__(self):
        """
        - Calls `setup_fetch_dirs(self)` to create directories for 
          story-lists, stories, and test files if they don't yet exist
        - Opens a new browser and returns webdriver instance
        - Loads creepypasta archive using Selenium
        """
        self.setup_fetch_dirs()
        # visit the page
        url = 'https://www.creepypasta.com/archive/?_orderby=date'
        self.driver = self.open_driver()
        self.driver.get(url)

    def open_driver(self):
        """
        - Called during `__init__`, but can also be executed on its own 
          to reset the browser
        - Closes last open driver if needed
        - Opens a new browser
        """
        # open driver
        try:
            driver.close()
        except:
            print("no webdrivers open")
        finally:
            driver = open_browser()
        return driver

    def setup_fetch_dirs(self):
        """
        - Creates directories for `page_source`.
        - This is where all files will be saved.
        """
        # create dirs for page_source
        # this is where all files will be saved
        self.list_pages_dir = "list-pages/"
        os.makedirs(self.list_pages_dir, exist_ok=True)
        self.story_pages_dir = "story-pages/"
        os.makedirs(self.story_pages_dir, exist_ok=True)
        self.test_dir = "test/"
        os.makedirs(self.test_dir, exist_ok=True)
    
    def close_popups(self):
        """        
        - Closes all popups that are visible on the page
        - Runs twice, to handle ads with delayed loading
        - Uses `CPLSeleniumAdHandler`'s methods
        """
        for i in range(2):
            CPLSeleniumAdHandler.close_first_popups(self.driver)
            CPLSeleniumAdHandler.close_some_ads(self.driver)
            time.sleep(2)

# %% [markdown]
# ## Close ads that block target elements

# %%
class CPLSeleniumAdHandler:    
    @classmethod
    # TODO: accept/reject popup
    def close_first_popups(cls, driver):
        """
        - `driver`: webdriver instance
        -  Closes popups that first appear as creepypasta page is loading
        """
        # todo: wait until load
        try:
            signup_updates_popup_element = driver.find_element(
                By.XPATH,
                '//*[@id="onesignal-slidedown-cancel-button"]'
            )
            signup_updates_popup_element.click()
        except:
            print("no signup popup element on page")
    
    @classmethod
    def close_some_ads(cls, driver):
        """
        - `driver`: webdriver instance
        - Closes more ads that render on the page after initial load
        - May want to run this on its own again for more delayed ads
        """
        try:
            pg_top_ad_element_to_close = driver.find_element(
                By.XPATH,
                '//*[@id="pw-close-btn"]'
            )
            pg_top_ad_element_to_close.click()
        except:
            print("no pg top ad element on page")

        try:
            pg_btm_ad_element_to_close = driver.find_element(
                By.XPATH,
                '//*[@id="pw-oop-bottom_rail"]/div[2]'
            )
            pg_btm_ad_element_to_close.click()
        except:
            print("no pg btm ad element on page")

        try:
            pg_btm_ad_element_to_close_2 = driver.find_element(
                By.XPATH,
                '//*[@id="pw-oop-bottom_rail2"]/div[2]'
            )
            pg_btm_ad_element_to_close_2.click()
        except:
            print("no pg btm ad 2 element on page")

# %% [markdown]
# ## Page Nav Functions

# %%
class CPLSeleniumPageNav:
    """
    Container for functions that navigate and save individual pages.
    """
    @classmethod
    def go_to_next_page(cls, driver):
        """
        - `driver`: webdriver instance
        - Navigates to next page
        - In a loop, stops advancing pages on final page
        """
        try:
            next_page_element = driver.find_element(
                By.XPATH,
                '//*[@id="post-40339"]/div/div[1]/div[4]/ul/li[8]/a'
            )
        except:
            # retry once in case element has not yet loaded
            # TODO: swap to implicit wait
            next_page_element = driver.find_element(
                By.XPATH,
                '//*[@id="post-40339"]/div/div[1]/div[4]/ul/li[8]/a'
            )
        # need to scroll down to click
        # otherwise action will be caught by iframe/ads
        scroll_into_view_js = 'document.querySelector("#post-40339 > div > div.pt-cv-wrapper > div.text-left.pt-cv-pagination-wrapper > ul > li.cv-pageitem-next > a").scrollIntoView();'
        driver.execute_script(scroll_into_view_js, next_page_element)
        driver.execute_script("window.scrollBy(0, -50);")

        # checking to see if clicking does anything, or if button is already "active"
        # todo: refactor to exclude already "active" (red) elements earlier?
        current_url = driver.current_url # before click
        print(current_url)
        next_page_element.click()
        print(driver.current_url)

        # if the "clicked" page is new, then return True
        # this will tell the calling function to use the results
        # and continue looping
        return (current_url != driver.current_url)
    
    @classmethod
    def reset_to_first_page(cls, driver):
        """
        - `driver`: webdriver instance
        - Navigates back to first page
        """
        try:
            next_page_element = driver.find_element(
                By.XPATH,
                '//*[@id="post-40339"]/div/div[1]/div[4]/ul/li[8]/a'
            )
        except:
            # retry once in case element has not yet loaded
            # TODO: swap to implicit wait
            next_page_element = driver.find_element(
                By.XPATH,
                '//*[@id="post-40339"]/div/div[1]/div[4]/ul/li[8]/a'
            )
        scroll_into_view_js = 'document.querySelector("#post-40339 > div > div.pt-cv-wrapper > div.text-left.pt-cv-pagination-wrapper > ul > li.cv-pageitem-next > a").scrollIntoView();'
        driver.execute_script(scroll_into_view_js, next_page_element)
        driver.execute_script("window.scrollBy(0, -50);")
        first_page_carrots = driver.find_element(
            By.XPATH,
            '//*[@id="post-40339"]/div/div[1]/div[4]/ul/li[1]/a'
        )
        first_page_carrots.click()
    
    @classmethod
    def save_current_page(cls, driver, dest_dir):
        """
        - `driver`: webdriver instance
        - `dest_dir`: directory files are saved to
        - Saves `driver.page_source` for rendered page
        - Default saves to `./list-pages/`, `./story-pages/`, `./test/`
        
        """
        dest = f"{dest_dir}{date.today()}_{driver.current_url.split('?')[-1]}.html"
        print(dest)
        source = driver.page_source
        with open(dest, 'w') as f:
            f.write(source)

# %% [markdown]
# # Loop through and save all pages

# %%
cplm = CPLSeleniumManager()
# Out:
# no webdrivers open

# %%
cplm.close_popups()
# Out:
# no pg top ad element on page
# no pg btm ad element on page
# no signup popup element on page
# no pg top ad element on page
# no pg btm ad 2 element on page

# %%
# testing
CPLSeleniumPageNav.go_to_next_page(cplm.driver)
# Out:
# https://www.creepypasta.com/archive/?_orderby=date
# https://www.creepypasta.com/archive/?_orderby=date&_page=2
# True

# %%
# testing
CPLSeleniumPageNav.reset_to_first_page(cplm.driver)

# %%
# testing
CPLSeleniumPageNav.save_current_page(cplm.driver, cplm.test_dir)
# Out:
# test/2023-07-26__orderby=date.html

# %%
def get_all_list_pages(cplmanager):
    """
    This function:
    - `cplmanager`: an instance of `CPLSeleniumManager`
    - Clicks through creepypasta.com's archive of stories using Selenium
    - Saves each list of stories (urls) to disk, default `list-pages/`
    """
    # run for page 1
    CPLSeleniumPageNav.save_current_page(cplmanager.driver, cplmanager.list_pages_dir)

    # do the looping now
    while True:
        time.sleep(2)
        if not CPLSeleniumPageNav.go_to_next_page(cplmanager.driver):
            break
        # todo: do a smarter wait, lol
        time.sleep(2)
        CPLSeleniumPageNav.save_current_page(cplmanager.driver, cplmanager.list_pages_dir)

# %%
get_all_list_pages(cplm)
# Out:
# list-pages/2023-07-26__orderby=date&_page=128.html
# https://www.creepypasta.com/archive/?_orderby=date&_page=128
# https://www.creepypasta.com/archive/?_orderby=date&_page=129
# list-pages/2023-07-26__orderby=date&_page=129.html
# https://www.creepypasta.com/archive/?_orderby=date&_page=129
# https://www.creepypasta.com/archive/?_orderby=date&_page=130
# list-pages/2023-07-26__orderby=date&_page=130.html
# https://www.creepypasta.com/archive/?_orderby=date&_page=130
# https://www.creepypasta.com/archive/?_orderby=date&_page=131
# list-pages/2023-07-26__orderby=date&_page=131.html
# https://www.creepypasta.com/archive/?_orderby=date&_page=131
# https://www.creepypasta.com/archive/?_orderby=date&_page=132
# list-pages/2023-07-26__orderby=date&_page=132.html
# https://www.creepypasta.com/archive/?_orderby=date&_page=132
# https://www.creepypasta.com/archive/?_orderby=date&_page=133
# list-pages/2023-07-26__orderby=date&_page=133.html
# https://www.creepypasta.com/archive/?_orderby=date&_page=133
# https://www.creepypasta.com/archive/?_orderby=date&_page=134
# list-pages/2023-07-26__orderby=date&_page=134.html
# https://www.creepypasta.com/archive/?_orderby=date&_page=134
# https://www.creepypasta.com/archive/?_orderby=date&_page=135
# list-pages/2023-07-26__orderby=date&_page=135.html
# https://www.creepypasta.com/archive/?_orderby=date&_page=135
# https://www.creepypasta.com/archive/?_orderby=date&_page=136
# list-pages/2023-07-26__orderby=date&_page=136.html
# https://www.creepypasta.com/archive/?_orderby=date&_page=136
# https://www.creepypasta.com/archive/?_orderby=date&_page=137
# list-pages/2023-07-26__orderby=date&_page=137.html
# https://www.creepypasta.com/archive/?_orderby=date&_page=137
# https://www.creepypasta.com/archive/?_orderby=date&_page=138
# list-pages/2023-07-26__orderby=date&_page=138.html
# https://www.creepypasta.com/archive/?_orderby=date&_page=138
# https://www.creepypasta.com/archive/?_orderby=date&_page=139
# list-pages/2023-07-26__orderby=date&_page=139.html
# https://www.creepypasta.com/archive/?_orderby=date&_page=139
# https://www.creepypasta.com/archive/?_orderby=date&_page=140
# list-pages/2023-07-26__orderby=date&_page=140.html
# https://www.creepypasta.com/archive/?_orderby=date&_page=140
# https://www.creepypasta.com/archive/?_orderby=date&_page=141
# list-pages/2023-07-26__orderby=date&_page=141.html
# https://www.creepypasta.com/archive/?_orderby=date&_page=141
# https://www.creepypasta.com/archive/?_orderby=date&_page=142
# list-pages/2023-07-26__orderby=date&_page=142.html
# https://www.creepypasta.com/archive/?_orderby=date&_page=142
# https://www.creepypasta.com/archive/?_orderby=date&_page=143
# list-pages/2023-07-26__orderby=date&_page=143.html
# https://www.creepypasta.com/archive/?_orderby=date&_page=143
# https://www.creepypasta.com/archive/?_orderby=date&_page=144
# list-pages/2023-07-26__orderby=date&_page=144.html
# https://www.creepypasta.com/archive/?_orderby=date&_page=144
# https://www.creepypasta.com/archive/?_orderby=date&_page=145
# list-pages/2023-07-26__orderby=date&_page=145.html
# https://www.creepypasta.com/archive/?_orderby=date&_page=145
# https://www.creepypasta.com/archive/?_orderby=date&_page=146
# list-pages/2023-07-26__orderby=date&_page=146.html
# https://www.creepypasta.com/archive/?_orderby=date&_page=146
# https://www.creepypasta.com/archive/?_orderby=date&_page=147
# list-pages/2023-07-26__orderby=date&_page=147.html
# https://www.creepypasta.com/archive/?_orderby=date&_page=147
# https://www.creepypasta.com/archive/?_orderby=date&_page=148
# list-pages/2023-07-26__orderby=date&_page=148.html
# https://www.creepypasta.com/archive/?_orderby=date&_page=148
# https://www.creepypasta.com/archive/?_orderby=date&_page=149
# list-pages/2023-07-26__orderby=date&_page=149.html
# https://www.creepypasta.com/archive/?_orderby=date&_page=149
# https://www.creepypasta.com/archive/?_orderby=date&_page=150
# list-pages/2023-07-26__orderby=date&_page=150.html
# https://www.creepypasta.com/archive/?_orderby=date&_page=150
# https://www.creepypasta.com/archive/?_orderby=date&_page=151
# list-pages/2023-07-26__orderby=date&_page=151.html
# https://www.creepypasta.com/archive/?_orderby=date&_page=151
# https://www.creepypasta.com/archive/?_orderby=date&_page=152
# list-pages/2023-07-26__orderby=date&_page=152.html
# https://www.creepypasta.com/archive/?_orderby=date&_page=152
# https://www.creepypasta.com/archive/?_orderby=date&_page=153
# list-pages/2023-07-26__orderby=date&_page=153.html
# https://www.creepypasta.com/archive/?_orderby=date&_page=153
# https://www.creepypasta.com/archive/?_orderby=date&_page=154
# list-pages/2023-07-26__orderby=date&_page=154.html
# https://www.creepypasta.com/archive/?_orderby=date&_page=154
# https://www.creepypasta.com/archive/?_orderby=date&_page=155
# list-pages/2023-07-26__orderby=date&_page=155.html
# https://www.creepypasta.com/archive/?_orderby=date&_page=155
# https://www.creepypasta.com/archive/?_orderby=date&_page=156
# list-pages/2023-07-26__orderby=date&_page=156.html
# https://www.creepypasta.com/archive/?_orderby=date&_page=156
# https://www.creepypasta.com/archive/?_orderby=date&_page=157
# list-pages/2023-07-26__orderby=date&_page=157.html
# https://www.creepypasta.com/archive/?_orderby=date&_page=157
# https://www.creepypasta.com/archive/?_orderby=date&_page=158
# list-pages/2023-07-26__orderby=date&_page=158.html
# https://www.creepypasta.com/archive/?_orderby=date&_page=158
# https://www.creepypasta.com/archive/?_orderby=date&_page=159
# list-pages/2023-07-26__orderby=date&_page=159.html
# https://www.creepypasta.com/archive/?_orderby=date&_page=159
# https://www.creepypasta.com/archive/?_orderby=date&_page=160
# list-pages/2023-07-26__orderby=date&_page=160.html
# https://www.creepypasta.com/archive/?_orderby=date&_page=160
# https://www.creepypasta.com/archive/?_orderby=date&_page=161
# list-pages/2023-07-26__orderby=date&_page=161.html
# https://www.creepypasta.com/archive/?_orderby=date&_page=161
# https://www.creepypasta.com/archive/?_orderby=date&_page=162
# list-pages/2023-07-26__orderby=date&_page=162.html
# https://www.creepypasta.com/archive/?_orderby=date&_page=162
# https://www.creepypasta.com/archive/?_orderby=date&_page=163
# list-pages/2023-07-26__orderby=date&_page=163.html
# https://www.creepypasta.com/archive/?_orderby=date&_page=163
# https://www.creepypasta.com/archive/?_orderby=date&_page=164
# list-pages/2023-07-26__orderby=date&_page=164.html
# https://www.creepypasta.com/archive/?_orderby=date&_page=164
# https://www.creepypasta.com/archive/?_orderby=date&_page=165
# list-pages/2023-07-26__orderby=date&_page=165.html
# https://www.creepypasta.com/archive/?_orderby=date&_page=165
# https://www.creepypasta.com/archive/?_orderby=date&_page=166
# list-pages/2023-07-26__orderby=date&_page=166.html
# https://www.creepypasta.com/archive/?_orderby=date&_page=166
# https://www.creepypasta.com/archive/?_orderby=date&_page=167
# list-pages/2023-07-26__orderby=date&_page=167.html
# https://www.creepypasta.com/archive/?_orderby=date&_page=167
# https://www.creepypasta.com/archive/?_orderby=date&_page=168
# list-pages/2023-07-26__orderby=date&_page=168.html
# https://www.creepypasta.com/archive/?_orderby=date&_page=168
# https://www.creepypasta.com/archive/?_orderby=date&_page=169
# list-pages/2023-07-26__orderby=date&_page=169.html
# https://www.creepypasta.com/archive/?_orderby=date&_page=169
# https://www.creepypasta.com/archive/?_orderby=date&_page=170
# list-pages/2023-07-26__orderby=date&_page=170.html
# https://www.creepypasta.com/archive/?_orderby=date&_page=170
# https://www.creepypasta.com/archive/?_orderby=date&_page=171
# list-pages/2023-07-26__orderby=date&_page=171.html
# https://www.creepypasta.com/archive/?_orderby=date&_page=171
# https://www.creepypasta.com/archive/?_orderby=date&_page=172
# list-pages/2023-07-26__orderby=date&_page=172.html
# https://www.creepypasta.com/archive/?_orderby=date&_page=172
# https://www.creepypasta.com/archive/?_orderby=date&_page=173
# list-pages/2023-07-26__orderby=date&_page=173.html
# https://www.creepypasta.com/archive/?_orderby=date&_page=173
# https://www.creepypasta.com/archive/?_orderby=date&_page=174
# list-pages/2023-07-26__orderby=date&_page=174.html
# https://www.creepypasta.com/archive/?_orderby=date&_page=174
# https://www.creepypasta.com/archive/?_orderby=date&_page=175
# list-pages/2023-07-26__orderby=date&_page=175.html
# https://www.creepypasta.com/archive/?_orderby=date&_page=175
# https://www.creepypasta.com/archive/?_orderby=date&_page=176
# list-pages/2023-07-26__orderby=date&_page=176.html
# https://www.creepypasta.com/archive/?_orderby=date&_page=176
# https://www.creepypasta.com/archive/?_orderby=date&_page=177
# list-pages/2023-07-26__orderby=date&_page=177.html
# https://www.creepypasta.com/archive/?_orderby=date&_page=177
# https://www.creepypasta.com/archive/?_orderby=date&_page=178
# list-pages/2023-07-26__orderby=date&_page=178.html
# https://www.creepypasta.com/archive/?_orderby=date&_page=178
# https://www.creepypasta.com/archive/?_orderby=date&_page=179
# list-pages/2023-07-26__orderby=date&_page=179.html
# https://www.creepypasta.com/archive/?_orderby=date&_page=179
# https://www.creepypasta.com/archive/?_orderby=date&_page=180
# list-pages/2023-07-26__orderby=date&_page=180.html
# https://www.creepypasta.com/archive/?_orderby=date&_page=180
# https://www.creepypasta.com/archive/?_orderby=date&_page=181
# list-pages/2023-07-26__orderby=date&_page=181.html
# https://www.creepypasta.com/archive/?_orderby=date&_page=181
# https://www.creepypasta.com/archive/?_orderby=date&_page=182
# list-pages/2023-07-26__orderby=date&_page=182.html
# https://www.creepypasta.com/archive/?_orderby=date&_page=182
# https://www.creepypasta.com/archive/?_orderby=date&_page=183
# list-pages/2023-07-26__orderby=date&_page=183.html
# https://www.creepypasta.com/archive/?_orderby=date&_page=183
# https://www.creepypasta.com/archive/?_orderby=date&_page=184
# list-pages/2023-07-26__orderby=date&_page=184.html
# https://www.creepypasta.com/archive/?_orderby=date&_page=184
# https://www.creepypasta.com/archive/?_orderby=date&_page=185
# list-pages/2023-07-26__orderby=date&_page=185.html
# https://www.creepypasta.com/archive/?_orderby=date&_page=185
# https://www.creepypasta.com/archive/?_orderby=date&_page=186
# list-pages/2023-07-26__orderby=date&_page=186.html
# https://www.creepypasta.com/archive/?_orderby=date&_page=186
# https://www.creepypasta.com/archive/?_orderby=date&_page=187
# list-pages/2023-07-26__orderby=date&_page=187.html
# https://www.creepypasta.com/archive/?_orderby=date&_page=187
# https://www.creepypasta.com/archive/?_orderby=date&_page=188
# list-pages/2023-07-26__orderby=date&_page=188.html
# https://www.creepypasta.com/archive/?_orderby=date&_page=188
# https://www.creepypasta.com/archive/?_orderby=date&_page=189
# list-pages/2023-07-26__orderby=date&_page=189.html
# https://www.creepypasta.com/archive/?_orderby=date&_page=189
# https://www.creepypasta.com/archive/?_orderby=date&_page=190
# list-pages/2023-07-26__orderby=date&_page=190.html
# https://www.creepypasta.com/archive/?_orderby=date&_page=190
# https://www.creepypasta.com/archive/?_orderby=date&_page=191
# list-pages/2023-07-26__orderby=date&_page=191.html
# https://www.creepypasta.com/archive/?_orderby=date&_page=191
# https://www.creepypasta.com/archive/?_orderby=date&_page=192
# list-pages/2023-07-26__orderby=date&_page=192.html
# https://www.creepypasta.com/archive/?_orderby=date&_page=192
# https://www.creepypasta.com/archive/?_orderby=date&_page=193
# list-pages/2023-07-26__orderby=date&_page=193.html
# https://www.creepypasta.com/archive/?_orderby=date&_page=193
# https://www.creepypasta.com/archive/?_orderby=date&_page=194
# list-pages/2023-07-26__orderby=date&_page=194.html
# https://www.creepypasta.com/archive/?_orderby=date&_page=194
# https://www.creepypasta.com/archive/?_orderby=date&_page=195
# list-pages/2023-07-26__orderby=date&_page=195.html
# https://www.creepypasta.com/archive/?_orderby=date&_page=195
# https://www.creepypasta.com/archive/?_orderby=date&_page=196
# list-pages/2023-07-26__orderby=date&_page=196.html
# https://www.creepypasta.com/archive/?_orderby=date&_page=196
# https://www.creepypasta.com/archive/?_orderby=date&_page=197
# list-pages/2023-07-26__orderby=date&_page=197.html
# https://www.creepypasta.com/archive/?_orderby=date&_page=197
# https://www.creepypasta.com/archive/?_orderby=date&_page=198
# list-pages/2023-07-26__orderby=date&_page=198.html
# https://www.creepypasta.com/archive/?_orderby=date&_page=198
# https://www.creepypasta.com/archive/?_orderby=date&_page=199
# list-pages/2023-07-26__orderby=date&_page=199.html
# https://www.creepypasta.com/archive/?_orderby=date&_page=199
# https://www.creepypasta.com/archive/?_orderby=date&_page=200
# list-pages/2023-07-26__orderby=date&_page=200.html
# https://www.creepypasta.com/archive/?_orderby=date&_page=200
# https://www.creepypasta.com/archive/?_orderby=date&_page=201
# list-pages/2023-07-26__orderby=date&_page=201.html
# https://www.creepypasta.com/archive/?_orderby=date&_page=201
# https://www.creepypasta.com/archive/?_orderby=date&_page=202
# list-pages/2023-07-26__orderby=date&_page=202.html
# https://www.creepypasta.com/archive/?_orderby=date&_page=202
# https://www.creepypasta.com/archive/?_orderby=date&_page=203
# list-pages/2023-07-26__orderby=date&_page=203.html
# https://www.creepypasta.com/archive/?_orderby=date&_page=203
# https://www.creepypasta.com/archive/?_orderby=date&_page=204
# list-pages/2023-07-26__orderby=date&_page=204.html
# https://www.creepypasta.com/archive/?_orderby=date&_page=204
# https://www.creepypasta.com/archive/?_orderby=date&_page=205
# list-pages/2023-07-26__orderby=date&_page=205.html
# https://www.creepypasta.com/archive/?_orderby=date&_page=205
# https://www.creepypasta.com/archive/?_orderby=date&_page=206
# list-pages/2023-07-26__orderby=date&_page=206.html
# https://www.creepypasta.com/archive/?_orderby=date&_page=206
# https://www.creepypasta.com/archive/?_orderby=date&_page=207
# list-pages/2023-07-26__orderby=date&_page=207.html
# https://www.creepypasta.com/archive/?_orderby=date&_page=207
# https://www.creepypasta.com/archive/?_orderby=date&_page=208
# list-pages/2023-07-26__orderby=date&_page=208.html
# https://www.creepypasta.com/archive/?_orderby=date&_page=208
# https://www.creepypasta.com/archive/?_orderby=date&_page=209
# list-pages/2023-07-26__orderby=date&_page=209.html
# https://www.creepypasta.com/archive/?_orderby=date&_page=209
# https://www.creepypasta.com/archive/?_orderby=date&_page=210
# list-pages/2023-07-26__orderby=date&_page=210.html
# https://www.creepypasta.com/archive/?_orderby=date&_page=210
# https://www.creepypasta.com/archive/?_orderby=date&_page=210

# %%
next_page_element = cplm.driver.find_element(
    By.XPATH,
    '//*[@id="post-40339"]/div/div[1]/div[4]/ul/li[8]/a'
)
scroll_into_view_js = 'document.querySelector("#post-40339 > div > div.pt-cv-wrapper > div.text-left.pt-cv-pagination-wrapper > ul > li.cv-pageitem-next > a").scrollIntoView();'
cplm.driver.execute_script(scroll_into_view_js, next_page_element)
cplm.driver.execute_script("window.scrollBy(0, -50);")
